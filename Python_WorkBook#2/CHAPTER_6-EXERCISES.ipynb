# %% [markdown]
# # CHAPTER 6  - `Strings`

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'
text[4]
# Out:
# 'n'

# %%
text[2:4]
# Out:
# 'si'

# %%
text[:4]
# Out:
# 'Busi'

# %%
text[4:]
# Out:
# 'ness Analytics'

# %%
text[-2]
# Out:
# 'c'

# %%
text[-4:-2]
# Out:
# 'ti'

# %%
text[-2:]
# Out:
# 'cs'

# %%
text[:-2]
# Out:
# 'Business Analyti'

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'
phrase1 = phrase.split()
for i in phrase1:
  if(i != 'to' and i != 'rule'):
    print("'"+ i + "'")
print("'"+phrase+"'")
# Out:
# 'One'
# 'Ring'
# 'them'
# 'all'
# 'One Ring to rule them all'

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while(True):
  name = input("Name: ")
  stripName = name.rstrip().capitalize()
  print(stripName)
  if(name == ""):
    break;
# Out:
# Name: John Rey ortigad
# John rey ortigad
# Name:
